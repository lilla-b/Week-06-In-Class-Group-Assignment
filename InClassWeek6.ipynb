# %%
import pandas as pd
import numpy as np

jeopardy_df = pd.read_csv("JEOPARDY_CSV.csv")
jeopardy_df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1         4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1    Air Date    216930 non-null  object
#  2    Round       216930 non-null  object
#  3    Category    216930 non-null  object
#  4    Value       216930 non-null  object
#  5    Question    216930 non-null  object
#  6    Answer      216928 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %%
jeopardy_df.columns = ['Show', 'Date', 'Round', 'Category', 'Value', 'Question', 'Answer']
jeopardy_df.head()
# Out:
#    Show        Date      Round                         Category  Value  \
# 0  4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1  4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2  4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3  4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4  4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy_df.Date = pd.to_datetime(jeopardy_df.Date)
jeopardy_df.head(100)
# Out:
#     Show       Date             Round                         Category  \
# 0   4680 2004-12-31         Jeopardy!                          HISTORY
# 1   4680 2004-12-31         Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES
# 2   4680 2004-12-31         Jeopardy!      EVERYBODY TALKS ABOUT IT...
# 3   4680 2004-12-31         Jeopardy!                 THE COMPANY LINE
# 4   4680 2004-12-31         Jeopardy!              EPITAPHS & TRIBUTES
# ..   ...        ...               ...                              ...
# 95  5957 2010-07-06  Double Jeopardy!                        SEE & SAY
# 96  5957 2010-07-06  Double Jeopardy!                       NEWS TO ME
# 97  5957 2010-07-06  Double Jeopardy!                IN THE DICTIONARY
# 98  5957 2010-07-06  Double Jeopardy!                    SCIENCE CLASS
# 99  5957 2010-07-06  Double Jeopardy!                   KIDS IN SPORTS
#
#       Value                                           Question         Answer
# ...

# %%
jeopardy_df['year'] = pd.DatetimeIndex(jeopardy_df['Date']).year
jeopardy_df.head()
group_year = jeopardy_df.groupby('year')
#type(group_shows)
group_year['Show'].nunique()
# Out:
# year
# 1984     23
# 1985     16
# 1986     25
# 1987     22
# 1988     22
# 1989     36
# 1990     73
# 1991     24
# 1992     32
# 1993     35
# 1994     19
# 1995     19
# 1996     83
# 1997    221
# 1998    223
# 1999    229
# 2000    225
# 2001    203
# 2002    114
# 2003    158
# 2004    220
# 2005    225
# 2006    230
# 2007    231
# 2008    232
# 2009    226
# 2010    231
# 2011    224
# 2012     19
# Name: Show, dtype: int64

# %%
jeopardy_df['Category'].nunique()
# Out:
# 27983

# %%
#group_category = jeopardy_df.groupby('Category')
group_category['Category'].count()
# Out:
# Category
#  A JIM CARREY FILM FESTIVAL    5
# "!"                            5
# "-ARES"                        5
# "-ICIAN" EXPEDITION            5
# "...OD" WORDS                  5
#                               ..
# “R” MOVIES                     5
# “SAINTS”                       4
# “SOUTH”                        5
# “STREETS”                      5
# “WH”AT IS IT?                  5
# Name: Category, Length: 27983, dtype: int64

# %%
jeopardy_df["Answer"].nunique()
# Out:
# 88236

# %%
group_QA=jeopardy_df.groupby(['Category', 'Answer'])
group_QA[]
